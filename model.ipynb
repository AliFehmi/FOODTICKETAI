# %% [markdown]
# JSON dataset

# %%
import numpy as np
import json
import glob

#Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

#spacy
import spacy
from nltk.corpus import stopwords

#visualization
import pyLDAvis
import pyLDAvis.gensim

import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

import re

# %%
def load_data(file):
    with open (file, "r", encoding="utf-8") as f:
        data = json.load(f)
    return data

def write_data(file, data):
    with open (file, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=4)

# %%
stopwords = stopwords.words("english")

# %%
# data = load_data("data_case2-1.json")
# data = [item for item in data if "Description" in item]
# data = [item for item in data if item.get("Description")]

# %%
# def lemmatization(text, allowed_postags=["NOUN", "ADJ", "VERB", "ADV"]):
#     nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
#     doc = nlp(text)
#     new_text = [token.lemma_ for token in doc if token.pos_ in allowed_postags]
#     return " ".join(new_text)

# def gen_words(text):
#     return gensim.utils.simple_preprocess(text, deacc=True)
# def remove_tags(text):
#     text = re.sub(r'^\s*(From|Sent|To|Subject).*$', '', text, flags=re.MULTILINE)
#     text = re.sub(r'<[^>]*>', '', text)
#     text = re.sub(r'{[^}]*}', '', text)
#     text = re.sub(r'"[^"]*"', '', text)
#     text = re.sub(r'![^"]*!', '', text)
#     text = re.sub(r'\[[^\]]*\]', '', text)
#     text = re.sub(r'https?://\S+|www\.\S+', '', text)
#     text = re.sub(r'\b\d{3}-\d{3}-\d{4}\b', 'phone number', text)
#     text = re.sub(r'[^\w\s]', '', text)
#     text = re.sub(r'[^\x00-\x7F]+', '', text)
#     text = re.sub(r'\s+', ' ', text).strip()
#     return text

# %%
# for item in data:
#     if isinstance(item["Description"], str):
#         original_text = item["Description"]
#         # Remove unwanted tags and patterns
#         cleaned_text = remove_tags(original_text)
#         # Apply lemmatization on the cleaned text
#         lemmatized_text = lemmatization(cleaned_text)
#         # Tokenize the lemmatized text
#         tokenized_words = gen_words(lemmatized_text)
#         # Update "Description" with the joined tokenized words
#         item["Description"] = " ".join(tokenized_words)
# write_data("data_processed.json", data)

# %%
data = load_data("data_processed.json")
# Out:
# [{'Resolved': '04/26/2024 07:53', 'Description': 'description', 'Custom field (Source)': 'Portal', 'Comment': '07/07/2023 06:59;5fb17b020dd553006f17ff0a;Working on it', 'Comment.1': '07/07/2023 07:03;5fb17b020dd553006f17ff0a;This should get moved to ERP', 'Comment.2': '07/07/2023 07:03;5fb17b020dd553006f17ff0a;Hi Darb,\n\nWe have escalated your request to our internal team to look into the technical issue.\n\nThanks,\n\nBrad - Partner Support', 'Comment.3': '07/07/2023 07:27;5fb29c170dd553006f224f06;h6. ðŸ\x8f³ï¸\x8f Message originally posted in [IT-4676|https://capitalareafoodbank.atlassian.net/browse/IT-4676] on 07/Jul/2023 07:27 AM\n\nThanks for escalating to IT.  We will check it out.', 'Comment.4': '07/07/2023 07:32;5fb29c170dd553006f224f06;h6. ðŸ\x8f³ï¸\x8f Message originally posted in [IT-4676|https://capitalareafoodbank.atlassian.net/browse/IT-4676] on 07/Jul/2023 07:31 AM\n\nThis is an internal note', 'Comment.5': '07/12/2023 10:13;5f05c9e30b38b10022652fe4;h6. ðŸ\x8f³ï¸\x8f Message originally posted by [~accountid:557058:f58131cb-b67d-43c7-b30d-6b58d40bd077] in [IT-4676|https://capitalareafoodbank.atlassian.net/browse/IT-4676] on 12/Jul/2023 10:13 AM\n\nThe linked issue - [PART-4341] has been resolved', 'Comment.6': "04/26/2024 07:53;557058:f58131cb-b67d-43c7-b30d-6b58d40bd077;Ticket migrated to a new Jira Project. An automation set the Resolution field to Done. This updated the Resolved (a date) field to today's date.  Prior to the migration the Resolve date was not used in metrics."}, {'Resolved': '08/15/2024 11:16', 'Description': 'write morning email confirm schedule pickup tomorrow so select pickup window am thoroughly review sign order leave recommend bring copy order question call phone number email', 'Custom field (Cause of issue)': 'Request of Customer Relations', 'Custom field (Request Category)': 'Orders - Pre delivery -> Cancelation', 'Custom field (Source)': 'Email to Jira', 'Comment': '08/14/2024 09:57;557058:f58131cb-b67d-43c7-b30d-6b58d40bd077;Hi system@sent-via.netsuite.com, \n\nWe just received your request for assistance. We will reply as soon as possible.\n\nThank you,\nCustomer Relations\nCapital Area Food Bank', 'Comment.1': '08/15/2024 11:14;712020:b15fa988-bc60-49b4-aa6f-e30b7a3629c1;Good morning,\n\nThank you for contacting customer support. I can confirm that this order has been cancelled.\n\nCharity'}, {'Resolved': '05/07/2024 12:45', 'Description': 'add case following order mangos case pg only', 'Custom field (Cause of issue)': 'Request of Customer Relations', 'Custom field (Request Category)': 'Orders - Pre delivery -> Produce Request', 'Custom field (Source)': 'Email to Jira', 'Comment': '05/07/2024 12:17;557058:f58131cb-b67d-43c7-b30d-6b58d40bd077;Hi spicepor@yahoo.com, \n\nWe just received your request for assistance. We will reply as soon as possible.\n\nThank you,\nCustomer Relations\nCapital Area Food Bank', 'Comment.1': '05/07/2024 12:44;712020:b15fa988-bc60-49b4-aa6f-e30b7a3629c1;Good afternoon,\n\nThank you for contacting customer support. Your order has been updated. \n\nCharity'}, {'Resolved': '05/28/2024 12:32', 'Description': 'add following order case so', 'Custom field (Cause of issue)': 'Request of Customer Relations', 'Custom field (Request Category)': 'Orders - Pre delivery -> Edit Order Items', 'Custom field (Source)': 'Email to Jira', 'Comment': '05/28/2024 11:55;557058:f58131cb-b67d-43c7-b30d-6b58d40bd077;Hi secretary@metrosda.org, \n\nWe just received your request for assistance. We will reply as soon as possible.\n\nThank you,\nCustomer Relations\nCapital Area Food Bank', 'Comment.1': '05/28/2024 12:26;712020:b15fa988-bc60-49b4-aa6f-e30b7a3629c1;Good afternoon, \n\nThank you for contacting customer service. I have updated your order. \n\nCharity'}, {'Resolved': '05/01/2024 10:55', 'Description': 'good morning add following order case case pg only', 'Custom field (Cause of issue)': 'Other', 'Custom field (Request Category)': 'Orders - Pre delivery -> Produce Request',  ...

# %%
print(data[0])
# Out:
# {'Resolved': '04/26/2024 07:53', 'Description': 'description', 'Custom field (Source)': 'Portal', 'Comment': '07/07/2023 06:59;5fb17b020dd553006f17ff0a;Working on it', 'Comment.1': '07/07/2023 07:03;5fb17b020dd553006f17ff0a;This should get moved to ERP', 'Comment.2': '07/07/2023 07:03;5fb17b020dd553006f17ff0a;Hi Darb,\n\nWe have escalated your request to our internal team to look into the technical issue.\n\nThanks,\n\nBrad - Partner Support', 'Comment.3': '07/07/2023 07:27;5fb29c170dd553006f224f06;h6. ðŸ\x8f³ï¸\x8f Message originally posted in [IT-4676|https://capitalareafoodbank.atlassian.net/browse/IT-4676] on 07/Jul/2023 07:27 AM\n\nThanks for escalating to IT.  We will check it out.', 'Comment.4': '07/07/2023 07:32;5fb29c170dd553006f224f06;h6. ðŸ\x8f³ï¸\x8f Message originally posted in [IT-4676|https://capitalareafoodbank.atlassian.net/browse/IT-4676] on 07/Jul/2023 07:31 AM\n\nThis is an internal note', 'Comment.5': '07/12/2023 10:13;5f05c9e30b38b10022652fe4;h6. ðŸ\x8f³ï¸\x8f Message originally posted by [~accountid:557058:f58131cb-b67d-43c7-b30d-6b58d40bd077] in [IT-4676|https://capitalareafoodbank.atlassian.net/browse/IT-4676] on 12/Jul/2023 10:13 AM\n\nThe linked issue - [PART-4341] has been resolved', 'Comment.6': "04/26/2024 07:53;557058:f58131cb-b67d-43c7-b30d-6b58d40bd077;Ticket migrated to a new Jira Project. An automation set the Resolution field to Done. This updated the Resolved (a date) field to today's date.  Prior to the migration the Resolve date was not used in metrics."}

# %%
# Extract values and collect unique ones using a set
unique_categories = set()

for item in data:
    if "Custom field (Request Category)" in item:
        unique_categories.add(item["Custom field (Request Category)"])

# Print the unique values
for value in unique_categories:
    print(value)
# Out:
# Menu -> Discrepancy
# Orders - Pre delivery -> Edit Order Items
# Spam / Duplicate
# Menu -> General Questions
# Delivery / Pickup
# PartnerLink -> New Shopper
# Feedback - Concern / Negative -> Transportation
# Orders - Pre delivery ->  Change to Pickup/vice versa
# Orders - Pre delivery -> Data/Time Change - Reschedule
# Agency Administration
# Delivery / Pickup -> Missing Item - Redeliver
# Menu -> Product Best By / Expiration Date
# Feedback - Concern / Negative -> Quality - Produce
# Orders - Pre delivery -> Produce Request
# Delivery / Pickup -> Return - Quality
# Orders - Pre delivery ->  Request unavailable window
# Billing / Grants -> Grant Support
# Billing / Grants -> Discrepancy in Invoice
# Billing / Grants -> Questions for Accounting
# Menu -> Inventory Availability
# Delivery / Pickup -> General Questions
# Spam / Duplicate -> Spam / Duplicate
# Orders - Pre delivery -> Cancelation
# Agency Administration -> Office Hours
# Delivery / Pickup -> Pallet Pickup
# Feedback - Concern / Negative -> Operations
# Agency Administration -> Update Information
# Billing / Grants -> General Questions
# Delivery / Pickup -> Missing Item - Refund
# Delivery / Pickup -> Request ETA / Status
# Orders - Pre delivery ->  Date/Time Change - New window
# PartnerLink -> General Questions
# Feedback - Concern / Negative -> Other / General
# PartnerLink
# Delivery / Pickup -> Report Issue
# Feedback - Concern / Negative -> Quality - Non Produce
# Agency Administration -> Connection to CAFB Staff
# Feedback - Positive -> Transportation
# Orders - Pre delivery -> General Questions
# Partner Produce Limit -> Question or Concern
# Orders - Pre delivery
# Agency Administration -> Partner Trainings
# PartnerLink -> ERP Issue
# Orders - Pre delivery -> Report Issue
# Return Notification -> Daily Report
# Partner Produce Limit -> Overage Alert
# Delivery / Pickup -> Return - Not Ordered

# %%
# Extract values and collect unique ones using a set
unique_categories = set()

for item in data:
    if "Custom field (Cause of issue)" in item:
        unique_categories.add(item["Custom field (Cause of issue)"])

# Print the unique values
for value in unique_categories:
    print(value)
# Out:
# Partner Error
# Partner Knowledge/Training
# Menu Discrepancy
# System Error
# Other
# Request of Customer Relations
# Ops Issue

# %%
data_words = [str(item["Description"]).split() for item in data if "Description" in item]

# %%
print(data_words[1])
# Out:
# ['write', 'morning', 'email', 'confirm', 'schedule', 'pickup', 'tomorrow', 'so', 'select', 'pickup', 'window', 'am', 'thoroughly', 'review', 'sign', 'order', 'leave', 'recommend', 'bring', 'copy', 'order', 'question', 'call', 'phone', 'number', 'email']

# %% [markdown]
# data_words object contains a list for each document (description) and each element in the list is a word that is preprocessed. So it is in BoW (Bag of Words) format.

# %%
#BIGRAMS AND TRIGRAMS
bigram_phrases = gensim.models.Phrases(data_words, min_count=5, threshold=50)
trigram_phrases = gensim.models.Phrases(bigram_phrases[data_words], threshold=50)

bigram = gensim.models.phrases.Phraser(bigram_phrases)
trigram = gensim.models.phrases.Phraser(trigram_phrases)

def make_bigrams(texts):
    return([bigram[doc] for doc in texts])

def make_trigrams(texts):
    return ([trigram[bigram[doc]] for doc in texts])

data_bigrams = make_bigrams(data_words)
data_bigrams_trigrams = make_trigrams(data_bigrams)

print (data_bigrams_trigrams[0][0:20])
# Out:
# ['description']

# %%
print(data_bigrams[1])
print(data_bigrams_trigrams[1])
# Out:
# ['write', 'morning', 'email', 'confirm', 'schedule', 'pickup', 'tomorrow', 'so', 'select', 'pickup', 'window', 'am', 'thoroughly_review', 'sign', 'order', 'leave', 'recommend', 'bring', 'copy', 'order', 'question', 'call', 'phone_number', 'email']
# ['write', 'morning', 'email', 'confirm', 'schedule', 'pickup', 'tomorrow', 'so', 'select', 'pickup', 'window', 'am', 'thoroughly_review', 'sign', 'order', 'leave', 'recommend', 'bring', 'copy', 'order', 'question', 'call_phone_number', 'email']

# %% [markdown]
# Here bigrams and trigrams are created but some of them are filtered out. The n_gram phrase must have occurred at least min_count times and the score must be at least as much as threshold value which is defined by the following;
# score(w1, w2) = count(w1, w2) / (count(w1) x count(w2))
# intuitively it gives the proportion of two words occurring together than they occur individually by chance, shows how relevant the n_gram is.

# %%
from gensim.models import TfidfModel
from gensim import corpora

texts = data_bigrams_trigrams

# Step 1: Build initial dictionary and corpus
id2word = corpora.Dictionary(texts)
corpus = [id2word.doc2bow(text) for text in texts]

# Step 2: Create TF-IDF model
tfidf = TfidfModel(corpus, id2word=id2word)

low_value = 0.2  # Try a much higher threshold

# Step 3: Clean both texts and corpus
filtered_texts = []
filtered_corpus = []

for i, bow in enumerate(corpus):
    tfidf_weights = tfidf[bow]
    tfidf_ids = {id for id, score in tfidf_weights if score >= low_value}
    bow_ids = {id for id, _ in bow}
    allowed_ids = tfidf_ids & bow_ids

    # Filtered BoW and Text
    new_bow = [b for b in bow if b[0] in allowed_ids]
    new_text = [id2word[b[0]] for b in new_bow]

    filtered_corpus.append(new_bow)
    filtered_texts.append(new_text)

# Step 4: Rebuild dictionary and final corpus from cleaned text
id2word = corpora.Dictionary(filtered_texts)
corpus = [id2word.doc2bow(text) for text in filtered_texts]

# %% [markdown]
# Corpus[n] represents the n-th document, each tuple (a, b) where a is the index of the word which is saved in the id2word[a] and b is the frequency of that word in that document.

# %%
print(corpus[3])
print(id2word[9])
print(id2word[16])
# Out:
# [(12, 1), (13, 1), (17, 1), (18, 1)]
# sign
# pg

# %%
print(data_words[1])
# Out:
# ['write', 'morning', 'email', 'confirm', 'schedule', 'pickup', 'tomorrow', 'so', 'select', 'pickup', 'window', 'am', 'thoroughly', 'review', 'sign', 'order', 'leave', 'recommend', 'bring', 'copy', 'order', 'question', 'call', 'phone', 'number', 'email']

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=13,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha="auto",
                                           per_word_topics=True)

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word, mds="mmds", R=10)
vis
# Out:
# /Users/alifehmiyildiz/.pyenv/versions/3.8.10/lib/python3.8/site-packages/sklearn/manifold/_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 10    -0.342818  0.187861       1        1  14.828409
# 12     0.060866 -0.396432       2        1  11.947655
# 4     -0.126841  0.334074       3        1  11.432501
# 0      0.122236  0.365855       4        1   9.340483
# 6     -0.228707  0.027919       5        1   7.356994
# 5      0.304324  0.090457       6        1   7.335115
# 1      0.284738 -0.074905       7        1   7.223344
# 9     -0.325637 -0.166960       8        1   6.236478
# 8      0.215459 -0.229590       9        1   5.962586
# 11     0.156122  0.173787      10        1   5.825248
# 2     -0.119925 -0.257267      11        1   5.361375
# 7     -0.047951 -0.071928      12        1   3.991349
# 3      0.048135  0.017127      13        1   3.158464, topic_info=           Term       Freq      Total Category  logprob  loglift
# 12         case  49.000000  49.000000  Default  10.0000  10.0000
# 295     invoice  43.000000  43.000000  Default   9.0000   9.0000
# 37         edit  45.000000  45.000000  Default   8.0000   8.0000
# 121     produce  36.000000  36.000000  Default   7.0000   7.0000
# 753       thank  32.000000  32.000000  Default   6.0000   6.0000
# ...         ...        ...        ...      ...      ...      ...
# 568   community   2.976955   3.765337  Topic13  -3.9914   3.2201
# 171        send   2.573090   3.361470  Topic13  -4.1372   3.1878
# 804       issue   2.478489   3.266870  Topic13  -4.1747   3.1789
# 669     process   2.166440   2.954822  Topic13  -4.3092   3.1447
# 1260      clear   2.102676   2.891065  Topic13  -4.3391   3.1367
#
# [151 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 325      13  0.949089        able
# 835      10  0.908306       about
# 145      11  0.884788     account
# 17        2  0.977152         add
# 116       5  0.951535  additional
# ...     ...       ...         ...
# 931       2  0.755344      unable
# 931       9  0.211496      unable
# 185       5  0.924365        want
# 11        9  0.865901      window
# 96        2  0.969755   yesterday
#
# [148 rows x 3 columns], R=10, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[11, 13, 5, 1, 7, 6, 2, 10, 9, 12, 3, 8, 4])
